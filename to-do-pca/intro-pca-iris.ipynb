# %%
import seaborn as sns
sns.set(style="ticks")

df = sns.load_dataset("iris")
sns.pairplot(df, hue="species");

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn import decomposition
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

def transform(df): 
    df['species'] = df['species'].map({'setosa': 2, 'versicolor':1, 'virginica': 0})
    return df
df = transform(df)

X = df.drop('species',axis = 1)

from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(X)

pca = decomposition.PCA(n_components=3)
X_pca_scaled = pca.fit_transform(X_scaled)

print('Projecting {}d-dimensional data to 2D'.format(X_scaled.shape[1]))

plt.figure(figsize=(12,10))
plt.scatter(X_pca_scaled[:, 0], X_pca_scaled[:, 1], c=df['species'], alpha=0.7, s=40);
plt.colorbar()
plt.title('MNIST. PCA projection');
# Out:
# Projecting 4d-dimensional data to 2D

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame
