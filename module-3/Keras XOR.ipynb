# %% [markdown]
# # MASTER CLASS DEEP LEARNING - 101

# %% [markdown]
# Interesting links <br><br>
#     [Perceptron 101 y funciones de activacion](https://towardsdatascience.com/activation-functions-neural-networks-1cbd9f8d91d6)<br><br>
#     [Optimizadores](https://towardsdatascience.com/types-of-optimization-algorithms-used-in-neural-networks-and-ways-to-optimize-gradient-95ae5d39529f)<br><br>
#     [Learning Rate](https://towardsdatascience.com/understanding-learning-rates-and-how-it-improves-performance-in-deep-learning-d0d4059c1c10)<br><br>
#     [Playground Tensorflow](https://playground.tensorflow.org/)<br><br>

# %% [markdown]
# ___

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD
import numpy as np # This ain't part of keras but is useful AF

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

model = Sequential()
model.add(Dense(8, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

sgd = SGD(lr=0.1)
model.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])

model.fit(X, y, batch_size=1, epochs=1000)
print(model.predict_proba(X))
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 0s 42ms/step - loss: 0.8201 - acc: 0.5000
# Epoch 2/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.8018 - acc: 0.5000
# Epoch 3/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7838 - acc: 0.5000
# Epoch 4/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7710 - acc: 0.5000
# Epoch 5/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7632 - acc: 0.5000
# Epoch 6/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7576 - acc: 0.5000
# Epoch 7/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7529 - acc: 0.5000
# Epoch 8/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7488 - acc: 0.5000
# Epoch 9/1000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7420 - acc: 0.5000
# Epoch 10/1000
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7421 - acc: 0.5000
# Epoch 11/1000
# ...

# %% [markdown]
# ___
